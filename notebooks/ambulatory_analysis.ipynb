# %% [markdown]
# # Synthea
# Ambulatory Patients - First Encounter, 10k Patients

# %% [markdown]
# ## Libraries and Constants

# %%
import subprocess

from pathlib import Path
import shutil
import pandas as pd

# Absolute paths to files and directories
BASE_DIRECTORY = (Path.cwd()).parent
SYNTHEA_PATH = Path(BASE_DIRECTORY / 'synthea-with-dependencies.jar')
RAW_DATA_PATH = Path(BASE_DIRECTORY / 'data/raw/analysis')
CSV_RAW_DATA_PATH = Path(RAW_DATA_PATH / 'csv')
PROCESSED_DATA_PATH = Path(BASE_DIRECTORY / 'data/processed/analysis')

# Shell command to run Synthea
RUN_SYNTHEA = f'java -jar {SYNTHEA_PATH}'

# CSV files that will be excluded from the generated data
EXCLUDED_CSV_FILES = [
    'careplans.csv',
    'claims.csv',
    'claims_transactions.csv',
    'organizations.csv',
    'patient_expenses.csv',
    'payer_transitions.csv',
    'payers.csv',
    'providers.csv',
    'supplies.csv'
]

# Number of patients to be generated
NUM_PATIENTS = 10_000

# If new Synthea data should be generated
GENERATE_DATA = False

# %% [markdown]
# # Data Generation

# %%
if(GENERATE_DATA):
    # Verify if the raw data directory exists
    if RAW_DATA_PATH.exists():
        # Delete the directory
        shutil.rmtree(RAW_DATA_PATH)

    # String containing the CSV files that will not be generated
    excluded_files = ','.join(EXCLUDED_CSV_FILES)

    # Define the shell command to generate the Synthea data
    command = RUN_SYNTHEA \
                + f' -p {NUM_PATIENTS}' \
                + f' --exporter.baseDirectory={RAW_DATA_PATH}' \
                + ' --exporter.csv.export=true' \
                + f' --exporter.csv.excluded_files={excluded_files}' \
                + ' --exporter.metadata.export=false' \
                + ' --exporter.fhir.export=false' \
                + ' --exporter.fhir.transaction_bundle=false' \
                + ' --exporter.hospital.fhir.export=false' \
                + ' --exporter.practitioner.fhir.export=false'

    # Run Synthea
    subprocess.run(command, shell=True)

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ### Opening the Raw Data Files

# %%
# Get the raw data file names
raw_files = [file.name[:-4] for file in CSV_RAW_DATA_PATH.iterdir()]

# Load the DataFrames with raw data
dfs = dict()
for file in raw_files:
    dfs[file] = pd.read_csv(f'{CSV_RAW_DATA_PATH}/{file}.csv')

# %% [markdown]
# ### Finding the Ambulatory Patients

# %%
# Drop unnecessary encounter columns
dfs['encounters'] = dfs['encounters'] \
    .drop(columns=[
        'ORGANIZATION', 'PROVIDER', 'PAYER', 'BASE_ENCOUNTER_COST',
        'TOTAL_CLAIM_COST', 'PAYER_COVERAGE'
    ])

# Filter only emergency encounters
dfs['encounters'] = dfs['encounters'] \
    .query('ENCOUNTERCLASS == "ambulatory"') \
    .query('REASONDESCRIPTION.notnull()') \
    .reset_index(drop=True)

# Get the identifiers (encounters and patients)
encounters_ids = dfs['encounters']['Id'].tolist()
patients_ids = dfs['encounters']['PATIENT'].tolist()

# %%
dfs['encounters']
# Out:
#                                           Id                 START  \
# 0       ca5babe8-6014-eaef-7189-1f09e5280886  2019-06-15T07:47:26Z
# 1       32e6188c-8c10-d290-9774-cee197d5ad81  2019-06-18T20:47:26Z
# 2       9ee6c40f-fa70-cdf3-ed78-896c75ccb5f4  2019-07-01T13:47:26Z
# 3       05fa1752-d63b-92fe-bf6a-7aa1cd15690b  2015-02-28T07:57:10Z
# 4       8f4319ad-5a69-ecef-287a-d10504b5bd7d  2015-06-21T04:45:15Z
# ...                                      ...                   ...
# 419401  0ee31043-7e36-407d-f0c9-496f321ac59a  2014-04-03T03:23:31Z
# 419402  7d982820-cf8e-303c-f169-1e123ac45a09  2014-06-02T03:23:31Z
# 419403  6aae81a1-3087-e3fc-dcba-1dd71037cb61  2022-03-12T20:27:08Z
# 419404  786fd7c0-a13c-c60b-d250-bcf964f9aca6  2022-06-09T20:27:08Z
# 419405  80178af3-76fe-3ccf-bfc7-cd012a477120  2023-11-16T18:46:42Z
#
#                         STOP                               PATIENT  \
# 0       2019-06-15T08:02:26Z  17fdf07e-2189-49e3-3ff4-2fdcb99c062c
# 1       2019-06-18T21:02:26Z  17fdf07e-2189-49e3-3ff4-2fdcb99c062c
# 2       2019-07-01T14:16:43Z  17fdf07e-2189-49e3-3ff4-2fdcb99c062c
# 3       2015-02-28T08:12:10Z  c1ceda31-3ade-9760-437f-8eb454821bfc
# 4       2015-06-21T05:00:15Z  bbd6deca-6ab7-9347-4a20-276331a8825f
# ...                      ...                                   ...
# 419401  2014-04-03T03:38:31Z  291d0eaf-3b39-ce15-db1d-a2c5e29b8bb3
# 419402  2014-06-02T03:38:31Z  291d0eaf-3b39-ce15-db1d-a2c5e29b8bb3
# 419403  2022-03-12T20:42:08Z  291d0eaf-3b39-ce15-db1d-a2c5e29b8bb3
# 419404  2022-06-09T20:42:08Z  291d0eaf-3b39-ce15-db1d-a2c5e29b8bb3
# 419405  2023-11-16T19:01:42Z  291d0eaf-3b39-ce15-db1d-a2c5e29b8bb3
#
#        ENCOUNTERCLASS       CODE                      DESCRIPTION  \
# 0          ambulatory  185347001            Encounter for problem
# 1          ambulatory  185347001            Encounter for problem
# 2          ambulatory  185347001            Encounter for problem
# 3          ambulatory  185349003           Encounter for check up
# 4          ambulatory  185345009            Encounter for symptom
# ...               ...        ...                              ...
# 419401     ambulatory  390906007  Follow-up encounter (procedure)
# 419402     ambulatory  390906007  Follow-up encounter (procedure)
# 419403     ambulatory  185347001            Encounter for problem
# 419404     ambulatory  185349003           Encounter for check up
# 419405     ambulatory  185345009            Encounter for symptom
#
#          REASONCODE                                 REASONDESCRIPTION
# 0        24079001.0                                 Atopic dermatitis
# 1        24079001.0                                 Atopic dermatitis
# 2       419199007.0                    Allergy to substance (finding)
# 3       263102004.0                     Fracture subluxation of wrist
# 4       195662009.0                Acute viral pharyngitis (disorder)
# ...             ...                                               ...
# 419401   82423001.0                            Chronic pain (finding)
# 419402   82423001.0                            Chronic pain (finding)
# 419403  307731004.0  Injury of tendon of the rotator cuff of shoulder
# 419404  307731004.0  Injury of tendon of the rotator cuff of shoulder
# 419405  444814009.0                        Viral sinusitis (disorder)
#
# [419406 rows x 9 columns]

# %% [markdown]
# ### Filtering the Data Associated with the Infarction Emergency Encounters

# %%
# Filter data from DataFrames with encounter foreign key
for file in raw_files:
    if (file != 'encounters') and (file != 'patients'):
        dfs[file] = dfs[file] \
            .query('ENCOUNTER in @encounters_ids') \
            .reset_index(drop=True)

# # Drop unnecessary columns from immunizations, medications and procedures DataFrames
dfs['immunizations'] = dfs['immunizations'].drop(columns=['BASE_COST'])
dfs['medications'] = dfs['medications'] \
    .drop(columns=['BASE_COST', 'PAYER_COVERAGE', 'TOTALCOST'])
dfs['procedures'] = dfs['procedures'].drop(columns=['BASE_COST'])

# Filter data and drop unnecessary columns from the patients DataFrame
dfs['patients'] = dfs['patients'] \
    .drop(columns=['HEALTHCARE_EXPENSES', 'HEALTHCARE_COVERAGE', 'INCOME']) \
    .query('Id in @patients_ids') \
    .reset_index(drop=True)

# %% [markdown]
# ### Writing CSV Files with the Processed Data

# %%
# Verify if the processed data directory exists
if PROCESSED_DATA_PATH.exists():
    # Delete the directory
    shutil.rmtree(PROCESSED_DATA_PATH)

# Create the processed data directory
PROCESSED_DATA_PATH.mkdir(parents=True)

# Write CSV files with processed data
for file in raw_files:
    dfs[file].to_csv(f'{PROCESSED_DATA_PATH}/{file}.csv', index=False)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Treating the Encounters DataFrame

# %%
# Open the encounters data file
df_encounters = pd.read_csv(f'{PROCESSED_DATA_PATH}/encounters.csv')

# Drop unnecessary encounter columns
df_encounters_description = df_encounters \
    .drop(columns=[
        'START', 'STOP', 'PATIENT', 'ENCOUNTERCLASS', 'CODE', 'REASONCODE'
    ]) \
    .rename(columns={'Id': 'ENCOUNTER'})

# Print some of the encounters data
df_encounters_description.head()
# Out:
#                               ENCOUNTER             DESCRIPTION  \
# 0  ca5babe8-6014-eaef-7189-1f09e5280886   Encounter for problem
# 1  32e6188c-8c10-d290-9774-cee197d5ad81   Encounter for problem
# 2  9ee6c40f-fa70-cdf3-ed78-896c75ccb5f4   Encounter for problem
# 3  05fa1752-d63b-92fe-bf6a-7aa1cd15690b  Encounter for check up
# 4  8f4319ad-5a69-ecef-287a-d10504b5bd7d   Encounter for symptom
#
#                     REASONDESCRIPTION
# 0                   Atopic dermatitis
# 1                   Atopic dermatitis
# 2      Allergy to substance (finding)
# 3       Fracture subluxation of wrist
# 4  Acute viral pharyngitis (disorder)

# %%
df_encounters \
    .groupby(by=['REASONDESCRIPTION'], as_index=False) \
    .agg(CASES=('REASONCODE', 'count')) \
    .sort_values(by=['CASES'], ascending=False) \
    .reset_index(drop=True)
# Out:
#                                      REASONDESCRIPTION   CASES
# 0            Chronic kidney disease stage 4 (disorder)  168534
# 1                   End-stage renal disease (disorder)   81995
# 2                                     Normal pregnancy   30457
# 3                       Allergy to substance (finding)   19044
# 4                      Dependent drug abuse (disorder)   14319
# ..                                                 ...     ...
# 107                Tricuspid valve stenosis (disorder)       3
# 108  Fracture of the vertebral column with spinal c...       2
# 109                    Excessive salivation (disorder)       2
# 110                  Preinfarction syndrome (disorder)       2
# 111                             Meningocele (disorder)       1
#
# [112 rows x 2 columns]

# %% [markdown]
# ### Verifying the Number of Conditions per Encounter

# %%
# Open the conditions data file
df_conditions = pd.read_csv(f'{PROCESSED_DATA_PATH}/conditions.csv')

# Print some of the conditions data
df_conditions.head()
# Out:
#         START        STOP                               PATIENT  \
# 0  2019-06-15         NaN  17fdf07e-2189-49e3-3ff4-2fdcb99c062c
# 1  2015-06-21  2015-06-28  bbd6deca-6ab7-9347-4a20-276331a8825f
# 2  2021-10-11  2021-11-06  e2335115-b5f4-8b93-81b1-cc51d3af1835
# 3  2021-12-07  2021-12-19  e2335115-b5f4-8b93-81b1-cc51d3af1835
# 4  2019-10-28  2019-11-06  bbd6deca-6ab7-9347-4a20-276331a8825f
#
#                               ENCOUNTER       CODE  \
# 0  ca5babe8-6014-eaef-7189-1f09e5280886   24079001
# 1  8f4319ad-5a69-ecef-287a-d10504b5bd7d  195662009
# 2  826ee4b0-8bec-a8c3-6b17-ed40cd7786bd  444814009
# 3  e301defb-dcae-d3ee-5688-88b97c082acc   10509002
# 4  f50d4fd7-6d66-464a-829f-d152b16ff626   10509002
#
#                           DESCRIPTION
# 0                   Atopic dermatitis
# 1  Acute viral pharyngitis (disorder)
# 2          Viral sinusitis (disorder)
# 3         Acute bronchitis (disorder)
# 4         Acute bronchitis (disorder)

# %%
# Aggregate data using encounter codes
df_conditions_agg = df_conditions \
    .groupby(by=['ENCOUNTER'], as_index=False) \
    .agg(
        NUM_CONDITIONS=('CODE', pd.Series.nunique),
        CONDITIONS=('DESCRIPTION', 'unique')
    ) \
    .sort_values(by=['NUM_CONDITIONS'], ascending=False) \
    .reset_index(drop=True)

# Save a CSV file with the aggregation result
df_conditions_agg.to_csv(f'{PROCESSED_DATA_PATH}/agg_conditions.csv', index=False)

# Print some of the aggregation result
df_conditions_agg
# Out:
#                                   ENCOUNTER  NUM_CONDITIONS  \
# 0      c39ec22c-2a3f-b1b9-da87-69c3c17d2bd5              11
# 1      b9b5aaf9-ed48-207d-3be4-26bc61d43a57              11
# 2      a3832f5d-fa19-8d56-1782-6a8681c24d5f              11
# 3      8a136b8c-d25d-0d7c-90b1-d55e413ef9c5              10
# 4      17b19d1b-6b78-bd34-9542-bdf3853db573              10
# ...                                     ...             ...
# 48621  58d5dedd-daa6-249b-6254-7bde357525a6               1
# 48622  58d7b0fa-07b4-acbf-9815-084d5ec0b3e6               1
# 48623  58d7e549-d4df-3c68-96d9-7f8277fed837               1
# 48624  58d7fbec-b353-489b-6c8c-e03b8ac5138a               1
# 48625  ffff1a7c-d9aa-fdd4-22b2-e8d66676b1a3               1
#
#                                               CONDITIONS
# 0      [Headache (finding), Cough (finding), Sore thr...
# 1      [Cerebral palsy (disorder), Pain (finding), Po...
# 2      [Headache (finding), Cough (finding), Dyspnea ...
# 3      [Cough (finding), Sore throat symptom (finding...
# 4      [Cerebral palsy (disorder), Dystonia (disorder...
# ...                                                  ...
# 48621                       [Viral sinusitis (disorder)]
# 48622               [Idiopathic atrophic hypothyroidism]
# 48623                       [Viral sinusitis (disorder)]
# 48624                       [Viral sinusitis (disorder)]
# 48625                       [Viral sinusitis (disorder)]
#
# [48626 rows x 3 columns]

# %% [markdown]
# ### Verifying the Number of Observations per Encounter

# %%
# Open the observations data file
df_observations = pd.read_csv(f'{PROCESSED_DATA_PATH}/observations.csv')

# Print some of the observations data
df_observations.head()
# Out:
#                    DATE                               PATIENT  \
# 0  2019-06-18T20:47:26Z  17fdf07e-2189-49e3-3ff4-2fdcb99c062c
# 1  2019-06-18T20:47:26Z  17fdf07e-2189-49e3-3ff4-2fdcb99c062c
# 2  2019-06-18T20:47:26Z  17fdf07e-2189-49e3-3ff4-2fdcb99c062c
# 3  2019-06-18T20:47:26Z  17fdf07e-2189-49e3-3ff4-2fdcb99c062c
# 4  2015-06-21T04:45:15Z  bbd6deca-6ab7-9347-4a20-276331a8825f
#
#                               ENCOUNTER     CATEGORY     CODE  \
# 0  32e6188c-8c10-d290-9774-cee197d5ad81         exam  66519-0
# 1  32e6188c-8c10-d290-9774-cee197d5ad81         exam  66529-9
# 2  32e6188c-8c10-d290-9774-cee197d5ad81         exam  66524-0
# 3  32e6188c-8c10-d290-9774-cee197d5ad81         exam  66534-9
# 4  8f4319ad-5a69-ecef-287a-d10504b5bd7d  vital-signs   8310-5
#
#                                          DESCRIPTION VALUE UNITS     TYPE
# 0  Percentage area affected by eczema Head and Ne...  22.1     %  numeric
# 1   Percentage area affected by eczema Trunk [PhenX]   6.9     %  numeric
# 2  Percentage area affected by eczema Upper extre...   6.3     %  numeric
# 3  Percentage area affected by eczema Lower extre...   6.0     %  numeric
# 4                                   Body temperature  37.5   Cel  numeric

# %%
# Aggregate data using encounter codes
df_observations_agg = df_observations \
    .groupby(by=['ENCOUNTER'], as_index=False) \
    .agg(
        NUM_CATEGORIES=('CATEGORY', pd.Series.nunique),
        CATEGORIES=('CATEGORY', 'unique'),
        NUM_OBSERVATIONS=('CODE', pd.Series.nunique),
        OBSERVATIONS=('DESCRIPTION', 'unique')
    ) \
    .sort_values(by=['NUM_CATEGORIES', 'NUM_OBSERVATIONS'], ascending=False) \
    .reset_index(drop=True)

# Save a CSV file with the aggregation result
df_observations_agg.to_csv(f'{PROCESSED_DATA_PATH}/agg_observations.csv', index=False)

# Print some of the aggregation result
df_observations_agg
# Out:
#                                    ENCOUNTER  NUM_CATEGORIES  \
# 0       a6a73ec4-74ad-3e1c-3086-f6160ef5b57b               4
# 1       35939b53-1566-bc14-340c-0c1687f77829               4
# 2       23ce5d3b-6d8b-859b-41d3-24da934908ee               4
# 3       e17c8ef5-cd6c-ba89-a0f7-e42ec0666a0d               4
# 4       136c8057-653c-980e-0154-8fae54960b53               4
# ...                                      ...             ...
# 298558  ffecaabb-0622-01e2-e060-b1dd71a35e79               1
# 298559  fff40a75-b8db-65f5-ed5e-15ef4dc6fb1e               1
# 298560  fff77bfd-9637-28ae-462a-9e27d4d6b8d2               1
# 298561  fff84851-2899-8e94-7b96-88f6c4e27afa               1
# 298562  fffee29d-bc2f-bea6-b263-5bd0b3bd4b01               1
#
#                                    CATEGORIES  NUM_OBSERVATIONS  \
# 0       [procedure, survey, exam, laboratory]                29
# 1       [procedure, survey, exam, laboratory]                28
# 2       [procedure, survey, exam, laboratory]                27
# 3       [procedure, survey, exam, laboratory]                27
# 4       [procedure, survey, exam, laboratory]                26
# ...                                       ...               ...
# 298558                          [vital-signs]                 1
# 298559                          [vital-signs]                 1
# 298560                          [vital-signs]                 1
# 298561                          [vital-signs]                 1
# 298562                               [survey]                 1
#
#                                              OBSERVATIONS
# 0       [US Guidance for biopsy of Prostate, Within th...
# 1       [US Guidance for biopsy of Prostate, Within th...
# 2       [US Guidance for biopsy of Prostate, Within th...
# 3       [US Guidance for biopsy of Prostate, Within th...
# 4       [US Guidance for biopsy of Prostate, Within th...
# ...                                                   ...
# 298558                                 [Body temperature]
# 298559                                 [Body temperature]
# 298560                                 [Body temperature]
# 298561                                 [Body temperature]
# 298562                         [Pain severity - Reported]
#
# [298563 rows x 5 columns]

# %% [markdown]
# ### Verifying the Number of Conditions and Observations per Encounter

# %%
# Merge aggregation result for conditions and observations
df_merged_agg = df_conditions_agg \
    .merge(
        right=df_observations_agg,
        how='left',
        on='ENCOUNTER'
    ) \
    .sort_values(
        by=['NUM_CONDITIONS', 'NUM_CATEGORIES', 'NUM_OBSERVATIONS'],
        ascending=False
    ) \
    .fillna({
        'NUM_CATEGORIES': 0,
        'CATEGORIES': '',
        'NUM_OBSERVATIONS': 0,
        'OBSERVATIONS': ''
    }) \
    .astype({'NUM_CATEGORIES': int, 'NUM_OBSERVATIONS': int})

# Save a CSV file with the merge result
df_merged_agg.to_csv(f'{PROCESSED_DATA_PATH}/agg_conditions_observations.csv', index=False)

# Print some of the merge result
df_merged_agg
# Out:
#                                   ENCOUNTER  NUM_CONDITIONS  \
# 0      c39ec22c-2a3f-b1b9-da87-69c3c17d2bd5              11
# 2      a3832f5d-fa19-8d56-1782-6a8681c24d5f              11
# 1      b9b5aaf9-ed48-207d-3be4-26bc61d43a57              11
# 3      8a136b8c-d25d-0d7c-90b1-d55e413ef9c5              10
# 5      4ef07c79-a127-6985-2bb5-d6c1c31f2ad8              10
# ...                                     ...             ...
# 48621  58d5dedd-daa6-249b-6254-7bde357525a6               1
# 48622  58d7b0fa-07b4-acbf-9815-084d5ec0b3e6               1
# 48623  58d7e549-d4df-3c68-96d9-7f8277fed837               1
# 48624  58d7fbec-b353-489b-6c8c-e03b8ac5138a               1
# 48625  ffff1a7c-d9aa-fdd4-22b2-e8d66676b1a3               1
#
#                                               CONDITIONS  NUM_CATEGORIES  \
# 0      [Headache (finding), Cough (finding), Sore thr...               2
# 2      [Headache (finding), Cough (finding), Dyspnea ...               2
# 1      [Cerebral palsy (disorder), Pain (finding), Po...               0
# 3      [Cough (finding), Sore throat symptom (finding...               2
# 5      [Cough (finding), Sputum finding (finding), Fa...               2
# ...                                                  ...             ...
# 48621                       [Viral sinusitis (disorder)]               0
# 48622               [Idiopathic atrophic hypothyroidism]               0
# 48623                       [Viral sinusitis (disorder)]               0
# 48624                       [Viral sinusitis (disorder)]               0
# 48625                       [Viral sinusitis (disorder)]               0
#
#                       CATEGORIES  NUM_OBSERVATIONS  \
# 0      [vital-signs, laboratory]                17
# 2      [vital-signs, laboratory]                17
# 1                                                0
# 3      [vital-signs, laboratory]                17
# 5      [vital-signs, laboratory]                17
# ...                          ...               ...
# 48621                                            0
# 48622                                            0
# 48623                                            0
# 48624                                            0
# 48625                                            0
#
#                                             OBSERVATIONS
# 0      [Body temperature, Respiratory rate, Heart rat...
# 2      [Body temperature, Respiratory rate, Heart rat...
# 1
# 3      [Body temperature, Respiratory rate, Heart rat...
# 5      [Body temperature, Respiratory rate, Heart rat...
# ...                                                  ...
# 48621
# 48622
# 48623
# 48624
# 48625
#
# [48626 rows x 7 columns]

# %%
# Merge aggregation result for conditions and observations
df_merged_aggs = df_encounters_description \
    .merge(
        right=df_merged_agg,
        how='left',
        on='ENCOUNTER'
    ) \
    .sort_values(
        by=['NUM_CONDITIONS', 'NUM_CATEGORIES', 'NUM_OBSERVATIONS'],
        ascending=False
    ) \
    .fillna({
        'NUM_CONDITIONS': 0,
        'CONDITIONS': '',
        'NUM_CATEGORIES': 0,
        'CATEGORIES': '',
        'NUM_OBSERVATIONS': 0,
        'OBSERVATIONS': ''
    }) \
    .astype({'NUM_CATEGORIES': int, 'NUM_OBSERVATIONS': int})

# Save a CSV file with the merge result
# df_merged_aggs.to_csv(f'{PROCESSED_DATA_PATH}/agg_conditions_observations.csv', index=False)

# Print some of the merge result
df_merged_aggs
# Out:
#                                    ENCOUNTER  \
# 221977  a3832f5d-fa19-8d56-1782-6a8681c24d5f
# 223314  c39ec22c-2a3f-b1b9-da87-69c3c17d2bd5
# 268772  b9b5aaf9-ed48-207d-3be4-26bc61d43a57
# 18468   4ef07c79-a127-6985-2bb5-d6c1c31f2ad8
# 49663   123ba070-6cab-ef43-deb4-b9e4cbf4cac3
# ...                                      ...
# 419397  64b1d627-a3da-dec5-685e-2ccfa8625d25
# 419398  5ff3bc66-6d88-2bd7-6f93-1f2b411a041e
# 419401  0ee31043-7e36-407d-f0c9-496f321ac59a
# 419402  7d982820-cf8e-303c-f169-1e123ac45a09
# 419404  786fd7c0-a13c-c60b-d250-bcf964f9aca6
#
#                                               DESCRIPTION  \
# 221977                  Encounter for symptom (procedure)
# 223314                  Encounter for symptom (procedure)
# 268772  Physician visit with evaluation AND/OR managem...
# 18468                   Encounter for symptom (procedure)
# 49663                   Encounter for symptom (procedure)
# ...                                                   ...
# 419397                             Encounter for check up
# 419398                                       Office Visit
# 419401                    Follow-up encounter (procedure)
# 419402                    Follow-up encounter (procedure)
# 419404                             Encounter for check up
#
#                                         REASONDESCRIPTION  NUM_CONDITIONS  \
# 221977                                 Suspected COVID-19            11.0
# 223314                                 Suspected COVID-19            11.0
# 268772                          Cerebral palsy (disorder)            11.0
# 18468                                  Suspected COVID-19            10.0
# 49663                                  Suspected COVID-19            10.0
# ...                                                   ...             ...
# 419397  Screening for malignant neoplasm of colon (pro...             0.0
# 419398                     Alzheimer's disease (disorder)             0.0
# 419401                             Chronic pain (finding)             0.0
# 419402                             Chronic pain (finding)             0.0
# 419404   Injury of tendon of the rotator cuff of shoulder             0.0
#
#                                                CONDITIONS  NUM_CATEGORIES  \
# 221977  [Headache (finding), Cough (finding), Dyspnea ...               2
# 223314  [Headache (finding), Cough (finding), Sore thr...               2
# 268772  [Cerebral palsy (disorder), Pain (finding), Po...               0
# 18468   [Cough (finding), Sputum finding (finding), Fa...               2
# 49663   [Cough (finding), Sputum finding (finding), Fa...               2
# ...                                                   ...             ...
# 419397                                                                  0
# 419398                                                                  0
# 419401                                                                  0
# 419402                                                                  0
# 419404                                                                  0
#
#                        CATEGORIES  NUM_OBSERVATIONS  \
# 221977  [vital-signs, laboratory]                17
# 223314  [vital-signs, laboratory]                17
# 268772                                            0
# 18468   [vital-signs, laboratory]                17
# 49663   [vital-signs, laboratory]                17
# ...                           ...               ...
# 419397                                            0
# 419398                                            0
# 419401                                            0
# 419402                                            0
# 419404                                            0
#
#                                              OBSERVATIONS
# 221977  [Body temperature, Respiratory rate, Heart rat...
# 223314  [Body temperature, Respiratory rate, Heart rat...
# 268772
# 18468   [Body temperature, Respiratory rate, Heart rat...
# 49663   [Body temperature, Respiratory rate, Heart rat...
# ...                                                   ...
# 419397
# 419398
# 419401
# 419402
# 419404
#
# [419406 rows x 9 columns]

# %%
df_merged_aggs \
    .groupby(by=['REASONDESCRIPTION'], as_index=False) \
    .agg(
        CASES=('ENCOUNTER', 'count'),
        MEAN_CONDITIONS=('NUM_CONDITIONS', 'mean'),
        STD_CONDITIONS=('NUM_CONDITIONS', 'std'),
        MEAN_OBSERVATIONS=('NUM_OBSERVATIONS', 'mean'),
        STD_OBSERVATIONS=('NUM_OBSERVATIONS', 'std')
    ) \
    .sort_values(['MEAN_CONDITIONS', 'MEAN_OBSERVATIONS'], ascending=[False, True]) \
    .reset_index(drop=True) \
    .head(50)
# Out:
#                                     REASONDESCRIPTION  CASES  MEAN_CONDITIONS  \
# 0                                  Suspected COVID-19   1048         5.057252
# 1                                Neoplasm of prostate    293         1.597270
# 2                                  Bleeding from anus     60         1.216667
# 3               Suspected prostate cancer (situation)    207         1.169082
# 4               Mitral valve regurgitation (disorder)     59         1.016949
# 5                Streptococcal sore throat (disorder)   1641         1.007922
# 6                  Acute viral pharyngitis (disorder)   6907         1.006515
# 7       Localized  primary osteoarthritis of the hand    243         1.004115
# 8                              Osteoarthritis of knee    542         1.003690
# 9                          Viral sinusitis (disorder)  12168         1.001808
# 10                             Meningocele (disorder)      1         1.000000
# 11                   Mitral valve stenosis (disorder)     10         1.000000
# 12                  Preinfarction syndrome (disorder)      2         1.000000
# 13            Pulmonic valve regurgitation (disorder)      5         1.000000
# 14                 Pulmonic valve stenosis (disorder)     24         1.000000
# 15                               Rheumatoid arthritis     27         1.000000
# 16                    Spina bifida occulta (disorder)      4         1.000000
# 17           Tricuspid valve regurgitation (disorder)     16         1.000000
# 18                Tricuspid valve stenosis (disorder)      3         1.000000
# 19                      Primary fibromyalgia syndrome     31         1.000000
# 20                              Osteoarthritis of hip    193         1.000000
# 21  Screening for malignant neoplasm of breast (pr...    100         1.000000
# 22                         Congenital uterine anomaly    113         0.964602
# 23                        Acute bronchitis (disorder)   6028         0.956370
# 24             Complication occuring during pregnancy     79         0.936709
# 25                 Fetus with chromosomal abnormality    305         0.931148
# 26                                    Tubal pregnancy    232         0.875000
# 27                    Complete miscarriage (disorder)   1275         0.843922
# 28                                      Blighted ovum    592         0.817568
# 29                          Cerebral palsy (disorder)    219         0.808219
# 30               Acute bacterial sinusitis (disorder)   2227         0.796138
# 31                          Sleep disorder (disorder)    666         0.783784
# 32                               Sinusitis (disorder)   2723         0.757988
# 33                                               Gout    116         0.741379
# 34                 Idiopathic atrophic hypothyroidism     95         0.694737
# 35  Acute ST segment elevation myocardial infarcti...     22         0.681818
# 36  Abnormal findings diagnostic imaging heart+cor...    708         0.673729
# 37                        Meningomyelocele (disorder)     18         0.666667
# 38  Acute non-ST segment elevation myocardial infa...     61         0.622951
# 39                Primary malignant neoplasm of colon     74         0.608108
# 40                                  Atopic dermatitis    374         0.585561
# 41                        Perennial allergic rhinitis    275         0.578182
# 42  Perennial allergic rhinitis with seasonal vari...    328         0.570122
# 43                  Ischemic heart disease (disorder)   3434         0.569889
# 44                   Major depression  single episode    143         0.559441
# 45   Injury of tendon of the rotator cuff of shoulder    326         0.509202
# 46                         Seasonal allergic rhinitis    181         0.508287
# 47     Acquired immune deficiency syndrome (disorder)     41         0.390244
# 48                                     Polyp of colon    826         0.370460
# 49                   Aortic valve stenosis (disorder)    283         0.321555
#
#     STD_CONDITIONS  MEAN_OBSERVATIONS  STD_OBSERVATIONS
# 0         1.733033          14.541985          3.342893
# 1         1.073462          19.754266         26.654969
# 2         0.903696           0.000000          0.000000
# 3         0.535543           5.516908          9.439046
# 4         0.130189           0.000000          0.000000
# 5         0.088679           0.996953          0.107592
# 6         0.085688           0.997828          0.112219
# 7         0.064150           0.255144          0.436842
# 8         0.060690           0.328413          0.470070
# 9         0.138669           0.003369          0.081523
# 10             NaN           0.000000               NaN
# 11        0.000000           0.000000          0.000000
# 12        0.000000           0.000000          0.000000
# 13        0.000000           0.000000          0.000000
# 14        0.000000           0.000000          0.000000
# 15        0.000000           0.000000          0.000000
# 16        0.000000           0.000000          0.000000
# 17        0.000000           0.000000          0.000000
# 18        0.000000           0.000000          0.000000
# 19        0.000000           0.258065          0.444803
# 20        0.000000           0.316062          0.466147
# 21        0.000000           5.300000          5.786609
# 22        0.185607           0.000000          0.000000
# 23        0.225886           0.000995          0.044610
# 24        0.292723           0.000000          0.000000
# 25        0.253619           0.000000          0.000000
# 26        0.331434           0.000000          0.000000
# 27        0.371619           0.000000          0.000000
# 28        0.386527           0.000000          0.000000
# 29        2.238062           0.000000          0.000000
# 30        0.409592           0.001796          0.051886
# 31        0.443609           0.000000          0.000000
# 32        0.432647           0.000734          0.038327
# 33        0.459124           0.232759          0.424423
# 34        0.506840           0.000000          0.000000
# 35        0.476731           0.000000          0.000000
# 36        0.469179           3.984463          5.997740
# 37        0.485071           0.000000          0.000000
# 38        0.488669           0.000000          0.000000
# 39        0.544400           0.000000          0.000000
# 40        0.493285           0.000000          0.000000
# 41        0.494750           0.000000          0.000000
# 42        0.495815           0.000000          0.000000
# 43        0.495163           0.000000          0.000000
# 44        0.498199           0.000000          0.000000
# 45        0.512827           0.000000          0.000000
# 46        0.501318           0.000000          0.000000
# 47        0.891012           8.121951         24.594913
# 48        0.540078           0.215496          0.414351
# 49        0.475419           0.335689          4.122723
