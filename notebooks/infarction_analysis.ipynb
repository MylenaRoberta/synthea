# %% [markdown]
# # Synthea - Infarction Emergency Patients Analysis
# Only the first encounter is of interest

# %% [markdown]
# ## Libraries and Paths

# %%
from pathlib import Path
import shutil
import pandas as pd

# Absolute paths to files and directories
BASE_DIRECTORY = (Path.cwd()).parent
RAW_DATA_PATH = Path(BASE_DIRECTORY / 'data/raw/csv')
PROCESSED_DATA_PATH = Path(BASE_DIRECTORY / 'data/processed/infarction')
ANALYSIS_DATA_PATH = Path(BASE_DIRECTORY / 'data/analysis')

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ### Opening the Raw Data Files

# %%
# Get the raw data file names
raw_files = [file.name[:-4] for file in RAW_DATA_PATH.iterdir()]

# Load the DataFrames with raw data
dfs = dict()
for file in raw_files:
    dfs[file] = pd.read_csv(f'{RAW_DATA_PATH}/{file}.csv')

# %% [markdown]
# ### Finding the Infarction Emergency Patients

# %%
# Drop unnecessary encounter columns
dfs['encounters'] = dfs['encounters'].drop(
    columns=[
        'ORGANIZATION', 'PROVIDER', 'PAYER', 'BASE_ENCOUNTER_COST',
        'TOTAL_CLAIM_COST', 'PAYER_COVERAGE'
        ]
    )

# Filter only infarction emergency encounters
dfs['encounters'] = dfs['encounters'] \
    .query('ENCOUNTERCLASS == "emergency"') \
    .query('REASONDESCRIPTION.notnull()') \
    .query('REASONDESCRIPTION.str.contains("infarction")') \
    .reset_index(drop=True)

# Get the identifiers (encounters and patients)
encounters_ids = dfs['encounters']['Id'].tolist()
patients_ids = dfs['encounters']['PATIENT'].tolist()

# Print some of the filtered encounters data
dfs['encounters']
# Out:
#                                        Id                 START  \
# 0    f92d3c2e-d29a-6859-556a-de5b62f2d405  2019-05-16T07:29:34Z
# 1    e72a40cc-5242-64e3-775d-229d901b0c16  2013-06-19T20:49:32Z
# 2    adb82c2f-f58a-583b-0474-51c83eca5299  2007-04-05T18:34:48Z
# 3    f221d19b-db1f-6ae5-e5c2-71b6046757c6  2022-04-12T09:49:09Z
# 4    67dda16a-068b-d7e0-b4ec-27788d9bb39c  1995-07-04T15:24:01Z
# ..                                    ...                   ...
# 478  e5e08675-1b7f-cdf4-6081-0cb4e58f827d  2015-09-15T00:19:05Z
# 479  465dceea-fc96-b28c-1d30-74ecfd234c07  2020-05-31T07:04:36Z
# 480  3603363d-bb8d-755e-1eff-cf9e88e6ac5e  2018-01-14T02:14:47Z
# 481  2d504b1e-43e7-dab7-57bc-ac94df7921c8  1994-05-27T01:52:44Z
# 482  576bbd19-94f9-0e42-ebc0-4e8879b0f631  1984-09-26T09:51:20Z
#
#                      STOP                               PATIENT  \
# 0    2019-05-16T08:29:34Z  92ad977e-d82c-e187-f671-0505b402c337
# 1    2013-06-19T21:49:32Z  16313d4d-e097-4dc8-66c0-1e185f8b201d
# 2    2007-04-05T19:34:48Z  a8b96d79-17a8-fbd5-3d20-8be355fbf0c0
# 3    2022-04-12T10:49:09Z  7f48a3d6-971c-f431-d297-a96224ed0066
# 4    1995-07-04T16:24:01Z  fc8e0104-552d-8ea0-dc63-4f61b47380dd
# ..                    ...                                   ...
# 478  2015-09-15T01:19:05Z  ae5d46c2-17f3-2452-4eba-9c8f78676bd5
# 479  2020-05-31T08:04:36Z  ee788c26-624d-c903-dcdf-a800aba825c7
# 480  2018-01-14T03:14:47Z  d891f720-12cc-179f-51ea-e81eb4a2e0d0
# 481  1994-05-27T02:52:44Z  8aed6b40-9fb6-9e50-b534-fdd166046b04
# 482  1984-09-26T10:51:20Z  eb4b400c-ef63-8913-c637-b0099ef6e6df
#
#     ENCOUNTERCLASS      CODE                           DESCRIPTION  \
# 0        emergency  50849002  Emergency room admission (procedure)
# 1        emergency  50849002  Emergency room admission (procedure)
# 2        emergency  50849002  Emergency room admission (procedure)
# 3        emergency  50849002  Emergency room admission (procedure)
# 4        emergency  50849002  Emergency room admission (procedure)
# ..             ...       ...                                   ...
# 478      emergency  50849002  Emergency room admission (procedure)
# 479      emergency  50849002  Emergency room admission (procedure)
# 480      emergency  50849002  Emergency room admission (procedure)
# 481      emergency  50849002  Emergency room admission (procedure)
# 482      emergency  50849002  Emergency room admission (procedure)
#
#      REASONCODE                 REASONDESCRIPTION
# 0    22298006.0  Myocardial infarction (disorder)
# 1    22298006.0  Myocardial infarction (disorder)
# 2    22298006.0  Myocardial infarction (disorder)
# 3    22298006.0  Myocardial infarction (disorder)
# 4    22298006.0  Myocardial infarction (disorder)
# ..          ...                               ...
# 478  22298006.0  Myocardial infarction (disorder)
# 479  22298006.0  Myocardial infarction (disorder)
# 480  22298006.0  Myocardial infarction (disorder)
# 481  22298006.0  Myocardial infarction (disorder)
# 482  22298006.0  Myocardial infarction (disorder)
#
# [483 rows x 9 columns]

# %% [markdown]
# ### Filtering the Data Associated with the Infarction Emergency Encounters

# %%
# Filter data from DataFrames with encounter foreign key
for file in raw_files:
    if (file != 'encounters') and (file != 'patients'):
        dfs[file] = dfs[file] \
            .query('ENCOUNTER in @encounters_ids') \
            .reset_index(drop=True)

# # Drop unnecessary columns from immunizations, medications and procedures DataFrames
dfs['immunizations'] = dfs['immunizations'].drop(columns=['BASE_COST'])
dfs['medications'] = dfs['medications'] \
    .drop(columns=['BASE_COST', 'PAYER_COVERAGE', 'TOTALCOST'])
dfs['procedures'] = dfs['procedures'].drop(columns=['BASE_COST'])

# Filter data and drop unnecessary columns from the patients DataFrame
dfs['patients'] = dfs['patients'] \
    .drop(columns=['HEALTHCARE_EXPENSES', 'HEALTHCARE_COVERAGE', 'INCOME']) \
    .query('Id in @patients_ids') \
    .reset_index(drop=True)

# %% [markdown]
# ### Writing CSV Files with the Processed Data

# %%
# Verify if the processed data directory exists
if PROCESSED_DATA_PATH.exists():
    # Delete the directory
    shutil.rmtree(PROCESSED_DATA_PATH)

# Create the processed data directory
PROCESSED_DATA_PATH.mkdir(parents=True)

# Write CSV files with processed data
for file in raw_files:
    dfs[file].to_csv(f'{PROCESSED_DATA_PATH}/{file}.csv', index=False)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Verifying the Number of Conditions per Encounter

# %%
# Open the conditions data file
df_conditions = pd.read_csv(f'{PROCESSED_DATA_PATH}/conditions.csv')

# Aggregate conditions data using encounter codes
df_conditions_agg = df_conditions \
    .groupby(by=['ENCOUNTER'], as_index=False) \
    .agg(
        NUM_CONDITIONS=('CODE', pd.Series.nunique),
        CONDITIONS=('DESCRIPTION', 'unique')
    ) \
    .sort_values(by=['NUM_CONDITIONS'], ascending=False) \
    .reset_index(drop=True)

# Write a CSV file with the resulting DataFrame
df_conditions_agg.to_csv(f'{ANALYSIS_DATA_PATH}/infarction_conditions.csv', index=False)

# Print some of the aggregation result
df_conditions_agg
# Out:
#                                 ENCOUNTER  NUM_CONDITIONS  \
# 0    8798d7f0-4902-581f-2995-e3a022e62e6d               2
# 1    a028c6e9-dd5f-ea66-7e05-872ee839ecbc               2
# 2    9b687a55-12f2-bff6-d36d-94caef37c6f3               2
# 3    9b2e1576-df94-cc0a-c40f-497da59a3d61               2
# 4    9aa70fb7-2b48-480f-9f1f-3d9041b15778               2
# ..                                    ...             ...
# 478  3d26dc12-af0d-3b94-0eb6-2c60c932cf20               1
# 479  3c7f0b2e-6189-da1b-fbae-ac2cd1ececb8               1
# 480  3ae05fe2-aef6-f978-27cd-96028759b6ed               1
# 481  ad7269e6-9e30-7ac1-bf8e-421e31c09ee2               1
# 482  01a3790a-93ee-7d22-8dae-1fe780be02fb               1
#
#                                             CONDITIONS
# 0    [Myocardial infarction (disorder), Acute ST se...
# 1    [Myocardial infarction (disorder), Acute ST se...
# 2    [Myocardial infarction (disorder), Acute non-S...
# 3    [Myocardial infarction (disorder), Preinfarcti...
# 4    [Myocardial infarction (disorder), Acute ST se...
# ..                                                 ...
# 478  [Acute ST segment elevation myocardial infarct...
# 479  [Acute non-ST segment elevation myocardial inf...
# 480  [Acute ST segment elevation myocardial infarct...
# 481  [Acute non-ST segment elevation myocardial inf...
# 482  [Acute ST segment elevation myocardial infarct...
#
# [483 rows x 3 columns]

# %% [markdown]
# ### Verifying the Number of Observations per Encounter

# %%
# Open the observations data file
df_observations = pd.read_csv(f'{PROCESSED_DATA_PATH}/observations.csv')

# Aggregate data using encounter codes
df_observations_agg = df_observations \
    .groupby(by=['ENCOUNTER'], as_index=False) \
    .agg(
        NUM_CATEGORIES=('CATEGORY', pd.Series.nunique),
        CATEGORIES=('CATEGORY', 'unique'),
        NUM_OBSERVATIONS=('CODE', pd.Series.nunique),
        OBSERVATIONS=('DESCRIPTION', 'unique')
    ) \
    .sort_values(by=['NUM_CATEGORIES', 'NUM_OBSERVATIONS'], ascending=False) \
    .reset_index(drop=True)

# Write a CSV file with the resulting DataFrame
df_observations_agg.to_csv(f'{ANALYSIS_DATA_PATH}/infarction_observations.csv', index=False)

# Print some of the aggregation result
df_observations_agg
# Out:
#                                 ENCOUNTER  NUM_CATEGORIES  \
# 0    02aa36cf-0f8d-7da9-e3f3-a1d06ca2a14b               2
# 1    033dc170-f80e-b265-4382-1a0191e583c1               2
# 2    03fe0412-6dfa-2073-d16c-c2605f1396e7               2
# 3    053dff82-8641-83ab-5baa-ebcff4ebd555               2
# 4    092d9871-d219-f008-e9da-cbb6345791d0               2
# ..                                    ...             ...
# 255  fb1b3578-1b00-663e-28b7-e1d4750995ee               2
# 256  fca343f6-27f4-0500-d924-5296bf364435               2
# 257  fe218a9f-e4aa-9883-9674-8e11a59d29b8               2
# 258  ff014742-94fe-d3d9-5023-58af84b3e787               2
# 259  ffb80479-adc0-5850-5777-42a716f33a70               2
#
#                     CATEGORIES  NUM_OBSERVATIONS  \
# 0    [laboratory, vital-signs]                34
# 1    [laboratory, vital-signs]                34
# 2    [laboratory, vital-signs]                34
# 3    [laboratory, vital-signs]                34
# 4    [laboratory, vital-signs]                34
# ..                         ...               ...
# 255  [laboratory, vital-signs]                34
# 256  [laboratory, vital-signs]                34
# 257  [laboratory, vital-signs]                34
# 258  [laboratory, vital-signs]                34
# 259  [laboratory, vital-signs]                34
#
#                                           OBSERVATIONS
# 0    [Leukocytes [#/volume] in Blood by Automated c...
# 1    [Leukocytes [#/volume] in Blood by Automated c...
# 2    [Leukocytes [#/volume] in Blood by Automated c...
# 3    [Leukocytes [#/volume] in Blood by Automated c...
# 4    [Leukocytes [#/volume] in Blood by Automated c...
# ..                                                 ...
# 255  [Leukocytes [#/volume] in Blood by Automated c...
# 256  [Leukocytes [#/volume] in Blood by Automated c...
# 257  [Leukocytes [#/volume] in Blood by Automated c...
# 258  [Leukocytes [#/volume] in Blood by Automated c...
# 259  [Leukocytes [#/volume] in Blood by Automated c...
#
# [260 rows x 5 columns]

# %% [markdown]
# ### Joining Conditions and Observations Data

# %%
# Merge aggregation of conditions and aggregation of observations
df_merged_agg = df_conditions_agg \
    .merge(right=df_observations_agg, how='left', on='ENCOUNTER') \
    .fillna({
        'NUM_CATEGORIES': 0,
        'CATEGORIES': '',
        'NUM_OBSERVATIONS': 0,
        'OBSERVATIONS': ''
    }) \
    .astype({'NUM_CATEGORIES': int, 'NUM_OBSERVATIONS': int})

# Write a CSV file with the resulting DataFrame
df_merged_agg.to_csv(f'{ANALYSIS_DATA_PATH}/infarction_merged_data.csv', index=False)

# Print some of the merged data
df_merged_agg
# Out:
#                                 ENCOUNTER  NUM_CONDITIONS  \
# 0    8798d7f0-4902-581f-2995-e3a022e62e6d               2
# 1    a028c6e9-dd5f-ea66-7e05-872ee839ecbc               2
# 2    9b687a55-12f2-bff6-d36d-94caef37c6f3               2
# 3    9b2e1576-df94-cc0a-c40f-497da59a3d61               2
# 4    9aa70fb7-2b48-480f-9f1f-3d9041b15778               2
# ..                                    ...             ...
# 478  3d26dc12-af0d-3b94-0eb6-2c60c932cf20               1
# 479  3c7f0b2e-6189-da1b-fbae-ac2cd1ececb8               1
# 480  3ae05fe2-aef6-f978-27cd-96028759b6ed               1
# 481  ad7269e6-9e30-7ac1-bf8e-421e31c09ee2               1
# 482  01a3790a-93ee-7d22-8dae-1fe780be02fb               1
#
#                                             CONDITIONS  NUM_CATEGORIES  \
# 0    [Myocardial infarction (disorder), Acute ST se...               2
# 1    [Myocardial infarction (disorder), Acute ST se...               2
# 2    [Myocardial infarction (disorder), Acute non-S...               2
# 3    [Myocardial infarction (disorder), Preinfarcti...               2
# 4    [Myocardial infarction (disorder), Acute ST se...               2
# ..                                                 ...             ...
# 478  [Acute ST segment elevation myocardial infarct...               0
# 479  [Acute non-ST segment elevation myocardial inf...               0
# 480  [Acute ST segment elevation myocardial infarct...               0
# 481  [Acute non-ST segment elevation myocardial inf...               0
# 482  [Acute ST segment elevation myocardial infarct...               0
#
#                     CATEGORIES  NUM_OBSERVATIONS  \
# 0    [laboratory, vital-signs]                34
# 1    [laboratory, vital-signs]                34
# 2    [laboratory, vital-signs]                34
# 3    [laboratory, vital-signs]                34
# 4    [laboratory, vital-signs]                34
# ..                         ...               ...
# 478                                            0
# 479                                            0
# 480                                            0
# 481                                            0
# 482                                            0
#
#                                           OBSERVATIONS
# 0    [Leukocytes [#/volume] in Blood by Automated c...
# 1    [Leukocytes [#/volume] in Blood by Automated c...
# 2    [Leukocytes [#/volume] in Blood by Automated c...
# 3    [Leukocytes [#/volume] in Blood by Automated c...
# 4    [Leukocytes [#/volume] in Blood by Automated c...
# ..                                                 ...
# 478
# 479
# 480
# 481
# 482
#
# [483 rows x 7 columns]

# %% [markdown]
# ### Metrics of Conditions and Observations per Encounter

# %%
# Calculate the metrics of conditions and observations for encounters
df_metrics = df_merged_agg.describe()

# Write a CSV file with the resulting DataFrame
df_metrics.to_csv(f'{ANALYSIS_DATA_PATH}/infarction_metrics.csv', index=False)

# Print some of the metrics data
df_metrics
# Out:
#        NUM_CONDITIONS  NUM_CATEGORIES  NUM_OBSERVATIONS
# count      483.000000      483.000000        483.000000
# mean         1.540373        1.076605         18.302277
# std          0.498884        0.998095         16.967620
# min          1.000000        0.000000          0.000000
# 25%          1.000000        0.000000          0.000000
# 50%          2.000000        2.000000         34.000000
# 75%          2.000000        2.000000         34.000000
# max          2.000000        2.000000         34.000000
